# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
merged_df=pd.read_csv('/content/merged_trader_sentiment_data.csv')

# %%
merged_df.head()
# Out:
#                                       account symbol  execution_price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed   @107           7.9800
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed   @107           7.9855
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed   @107           7.9874
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed   @107           7.9894
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed   @107           7.9900
#
#    size_tokens  size_usd side     Timestamp IST  Start Position Direction  \
# 0        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 1       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 2       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 3         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
# 4         1.41     11.27  BUY  02-12-2024 22:50     1298.215466       Buy
#
#    closedPnL  ...                 time        Date  direction  is_profitable  \
# 0        0.0  ...  2024-10-27 03:33:20  2024-10-27          1          False
# 1        0.0  ...  2024-10-27 03:33:20  2024-10-27          1          False
# 2        0.0  ...  2024-10-27 03:33:20  2024-10-27          1          False
# 3        0.0  ...  2024-10-27 03:33:20  2024-10-27          1          False
# 4        0.0  ...  2024-10-27 03:33:20  2024-10-27          1          False
#
#     timestamp  value classification        date  Classification  \
# 0  1730007000     74          Greed  2024-10-27           Greed
# 1  1730007000     74          Greed  2024-10-27           Greed
# 2  1730007000     74          Greed  2024-10-27           Greed
# 3  1730007000     74          Greed  2024-10-27           Greed
# 4  1730007000     74          Greed  2024-10-27           Greed
#
#    implied_leverage
# 0          0.129424
# 1          1.147739
# 2          0.996059
# 3          0.054091
# 4          0.008681
#
# [5 rows x 26 columns]

# %% [markdown]
# # Statistical Tests

# %%
import numpy as np
from scipy.stats import ttest_ind, f_oneway

# Separate sentiment groups
fear_df = merged_df[merged_df["Classification"] == "Fear"]
greed_df = merged_df[merged_df["Classification"] == "Greed"]

# %% [markdown]
# T-Test: Profitability (closedPnL)

# %%
t_pnl, p_pnl = ttest_ind(
    fear_df["closedPnL"],
    greed_df["closedPnL"],
    equal_var=False
)

t_pnl, p_pnl
# Out:
# (np.float64(-5.864971964610066), np.float64(4.521489314640529e-09))

# %%
print("Significant difference" if p_pnl < 0.05 else "No significant difference")
# Out:
# Significant difference

# %% [markdown]
# T-Test: Implied Leverage

# %%
t_lev, p_lev = ttest_ind(
    fear_df["implied_leverage"],
    greed_df["implied_leverage"],
    equal_var=False
)

t_lev, p_lev
# Out:
# (np.float64(1.6710192804461648), np.float64(0.09472024627666556))

# %% [markdown]
# ANOVA

# %%
anova_pnl = f_oneway(
    fear_df["closedPnL"],
    greed_df["closedPnL"]
)

anova_pnl
# Out:
# F_onewayResult(statistic=np.float64(45.04466845607577), pvalue=np.float64(1.9320239996241292e-11))

# %%
print("Sentiment regime matters" if p_pnl < 0.05 else "Behavior changes more than outcomes")
# Out:
# Sentiment regime matters

# %% [markdown]
# # MACHINE LEARNINGMACHINE LEARNING

# %%
from sklearn.model_selection import StratifiedKFold, KFold, cross_val_score
from sklearn.metrics import (
    accuracy_score, f1_score, roc_auc_score,
    r2_score, mean_absolute_error
)
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %% [markdown]
# Target & Features

# %%
# Encode market sentiment (Fear = 0, Greed = 1)
merged_df["sentiment_binary"] = merged_df["Classification"].map({
    "Fear": 0,
    "Greed": 1
})

# %%
features = ["sentiment_binary", "size_usd", "implied_leverage", "Fee"]

# Classification target
merged_df["profitable"] = (merged_df["closedPnL"] > 0).astype(int)

X = merged_df[features]
y_cls = merged_df["profitable"]
y_reg = merged_df["closedPnL"]

# %% [markdown]
# # XGBoost
#  – Classification

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.0.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.28.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from xgboost) (1.16.3)

# %%
from xgboost import XGBClassifier, XGBRegressor

xgb_clf = XGBClassifier(
    n_estimators=300,
    max_depth=5,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="logloss",
    random_state=42
)

xgb_acc = cross_val_score(xgb_clf, X, y_cls, cv=cv_cls, scoring="accuracy")
xgb_f1  = cross_val_score(xgb_clf, X, y_cls, cv=cv_cls, scoring="f1")
xgb_auc = cross_val_score(xgb_clf, X, y_cls, cv=cv_cls, scoring="roc_auc")

# %%
xgb_acc.mean(), xgb_f1.mean(), xgb_auc.mean()
# Out:
# (np.float64(0.6448269668303197),
#  np.float64(0.498273969689811),
#  np.float64(0.7080825227416051))

# %% [markdown]
# # XGBoost – Regression

# %%
xgb_reg = XGBRegressor(
    n_estimators=400,
    max_depth=5,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

xgb_r2  = cross_val_score(xgb_reg, X, y_reg, cv=cv_reg, scoring="r2")
xgb_mae = -cross_val_score(xgb_reg, X, y_reg, cv=cv_reg, scoring="neg_mean_absolute_error")

# %%
xgb_r2.mean(), xgb_mae.mean()
# Out:
# (np.float64(0.0001827368254136985), np.float64(105.06967443405881))

# %% [markdown]
# FINAL RESULTS TABLE

# %%
xgb_classification_results = pd.DataFrame({
    "Model": ["XGBoost Classifier"],
    "CV Accuracy": [xgb_acc.mean()],
    "CV F1 Score": [xgb_f1.mean()],
    "CV ROC-AUC": [xgb_auc.mean()]
})

xgb_classification_results
# Out:
#                 Model  CV Accuracy  CV F1 Score  CV ROC-AUC
# 0  XGBoost Classifier     0.644827     0.498274    0.708083

# %%
xgb_regression_results = pd.DataFrame({
    "Model": ["XGBoost Regressor"],
    "CV R² Score": [xgb_r2.mean()],
    "CV MAE": [xgb_mae.mean()]
})

xgb_regression_results
# Out:
#                Model  CV R² Score      CV MAE
# 0  XGBoost Regressor     0.000183  105.069674

# %%
final_results = pd.DataFrame({
    "Model": ["XGBoost Classifier", "XGBoost Regressor"],
    "Task": ["Classification (Win/Loss)", "Regression (PnL)"],
    "Accuracy": [xgb_acc.mean(), None],
    "F1 Score": [xgb_f1.mean(), None],
    "ROC-AUC": [xgb_auc.mean(), None],
    "R² Score": [None, xgb_r2.mean()],
    "MAE": [None, xgb_mae.mean()]
})

final_results
# Out:
#                 Model                       Task  Accuracy  F1 Score  \
# 0  XGBoost Classifier  Classification (Win/Loss)  0.644827  0.498274
# 1   XGBoost Regressor           Regression (PnL)       NaN       NaN
#
#     ROC-AUC  R² Score         MAE
# 0  0.708083       NaN         NaN
# 1       NaN  0.000183  105.069674
